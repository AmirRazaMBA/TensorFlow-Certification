# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
path = tf.keras.utils.get_file('sunspots.csv', 
                               '  https://storage.googleapis.com/laurencemoroney-blog.appspot.com/Sunspots.csv')
print (path)
# Out:
# C:\Users\Amir\.keras\datasets\sunspots.csv

# %%
df = pd.read_csv(path, index_col='Date', parse_dates=True)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
df.columns = ['Sunspots']   # reaname column
df.plot(figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
print('Total months data: ' + str(len(df)) + ' years:' + str(len(df)//12))
# Out:
# Total months data: 3235 years:269

# %%
split_time = 3000

train = df[:split_time]
test = df[split_time:]

print('Total test months: ' + str(len(test)) + ' train months: ' + str(len(train)))
print('Total test years: ' + str(len(test)//12) + ' train years: ' + str(len(train)//12))
# Out:
# Total test months: 235 train months: 3000
# Total test years: 19 train years: 250

# %%
scaler = MinMaxScaler()
scaler.fit(train)
train = scaler.transform(train)
test = scaler.transform(test)

# %%
# 60 months = 5 years data for the the time window size
n_input = 60
n_features = 1
n_batch_size = 256

# %%
train_generator = TimeseriesGenerator(train, 
                                train, 
                                length = n_input, 
                                batch_size = n_batch_size)

# %%
x, y = train_generator[1]
print(x.shape)
print(y.shape)
# Out:
# (256, 60, 1)
# (256, 1)

# %%
model = Sequential()
model.add(LSTM(60, return_sequences=True, input_shape = (n_input,n_features)))
model.add(LSTM(60))
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1))

# %%
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))

# %%
optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)

# %%
model.compile(loss=tf.keras.losses.Huber(),
              optimizer=optimizer,
              metrics=["mae"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 60, 60)            14880
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 60)                29040
# _________________________________________________________________
# dense (Dense)                (None, 30)                1830
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                310
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 46,071
# Trainable params: 46,071
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_generator, epochs=10, callbacks=[lr_schedule])
# Out:
# Epoch 1/10
# 12/12 [==============================] - 2s 170ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 2/10
# 12/12 [==============================] - 2s 159ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 3/10
# 12/12 [==============================] - 2s 145ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 4/10
# 12/12 [==============================] - 2s 148ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 5/10
# 12/12 [==============================] - 2s 208ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 6/10
# 12/12 [==============================] - 2s 175ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 7/10
# 12/12 [==============================] - 2s 152ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 8/10
# 12/12 [==============================] - 2s 201ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 9/10
# 12/12 [==============================] - 2s 186ms/step - loss: 0.0388 - mae: 0.2150
# Epoch 10/10
# 12/12 [==============================] - 2s 172ms/step - loss: 0.0388 - mae: 0.2149

# %%
pred_list = []

batch = train[-n_input:].reshape((1, n_input, n_features))   # stepping stone value

for i in range(n_input):   
    pred_list.append(model.predict(batch)[0])                # predict and save in list
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1) # next value for prediction

# %%
df_predict = pd.DataFrame(scaler.inverse_transform(pred_list),
                          index=df[-n_input:].index, 
                          columns=['Prediction'])

# %%
df_test = pd.concat([df,df_predict], axis=1)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(df_test.iloc[-n_input:, [0]], df_test.iloc[-n_input:, [1]])) #error acceptable?
# Out:
# 71.18558231259209

# %%
plt.figure(figsize=(20, 8))
plt.plot(df_test.index, df_test['Sunspots'])
plt.plot(df_test.index, df_test['Prediction'], color='r')
plt.legend(["Sunspots", "Prediction"], loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()

# %%
# This time train is using the full df for the future forecasting
train = df
len(train)

scaler.fit(train)
train = scaler.transform(train)

generator = TimeseriesGenerator(train, 
                                train, 
                                length = n_input, 
                                batch_size = n_batch_size)

# %%
model.fit(generator,epochs=100)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 160ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 2/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 3/100
# 13/13 [==============================] - 2s 171ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 4/100
# 13/13 [==============================] - 2s 156ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 5/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 6/100
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 7/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 8/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 9/100
# 13/13 [==============================] - 2s 166ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 10/100
# 13/13 [==============================] - 2s 142ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 11/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 12/100
# 13/13 [==============================] - 2s 138ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 13/100
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 14/100
# 13/13 [==============================] - 2s 139ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 15/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 16/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 17/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 18/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 19/100
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 20/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 21/100
# 13/13 [==============================] - 2s 177ms/step - loss: 0.0381 - mae: 0.2131 1s - loss: 0.0405 - ma
# Epoch 22/100
# 13/13 [==============================] - 2s 184ms/step - loss: 0.0381 - mae: 0.2131 0s - loss: 0.0381 - mae: 0.213
# Epoch 23/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 24/100
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 25/100
# 13/13 [==============================] - 2s 192ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 26/100
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 27/100
# 13/13 [==============================] - 2s 190ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 28/100
# 13/13 [==============================] - 2s 178ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 29/100
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 30/100
# 13/13 [==============================] - 2s 136ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 31/100
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 32/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 33/100
# 13/13 [==============================] - 2s 186ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 34/100
# 13/13 [==============================] - 2s 176ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 35/100
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 36/100
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0381 - mae: 0.2131 1s - loss: 0.0366 - m
# Epoch 37/100
# 13/13 [==============================] - 2s 149ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 38/100
# 13/13 [==============================] - 2s 153ms/step - loss: 0.0381 - mae: 0.2131
# Epoch 39/100
# 13/13 [==============================] - 2s 156ms/step - loss: 0.0381 - mae: 0.2130
# Epoch 40/100
# 13/13 [==============================] - 2s 185ms/step - loss: 0.0381 - mae: 0.2130 0s - loss: 0.0394 - mae: 0.21
# Epoch 41/100
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0381 - mae: 0.2130
# Epoch 42/100
# 13/13 [==============================] - 2s 157ms/step - loss: 0.0381 - mae: 0.2130
# Epoch 43/100
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0381 - mae: 0.2130
# Epoch 44/100
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0380 - mae: 0.2130 0s - loss: 0.0380 - mae: 0.2
# Epoch 45/100
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 46/100
# 13/13 [==============================] - 3s 226ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 47/100
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 48/100
# 13/13 [==============================] - 2s 183ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 49/100
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 50/100
# 13/13 [==============================] - 2s 187ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 51/100
# 13/13 [==============================] - 2s 180ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 52/100
# 13/13 [==============================] - 2s 165ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 53/100
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 54/100
# 13/13 [==============================] - 3s 195ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 55/100
# 13/13 [==============================] - 2s 180ms/step - loss: 0.0380 - mae: 0.2130 1s - loss: 0.0375 - m
# Epoch 56/100
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 57/100
# 13/13 [==============================] - 3s 192ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 58/100
# 13/13 [==============================] - 2s 190ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 59/100
# 13/13 [==============================] - 2s 158ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 60/100
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 61/100
# 13/13 [==============================] - 2s 169ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 62/100
# 13/13 [==============================] - 2s 143ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 63/100
# 13/13 [==============================] - 2s 141ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 64/100
# 13/13 [==============================] - 2s 144ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 65/100
# 13/13 [==============================] - 2s 157ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 66/100
# 13/13 [==============================] - 2s 161ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 67/100
# 13/13 [==============================] - 2s 152ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 68/100
# 13/13 [==============================] - 2s 159ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 69/100
# 13/13 [==============================] - 2s 167ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 70/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 71/100
# 13/13 [==============================] - 2s 173ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 72/100
# 13/13 [==============================] - 3s 241ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 73/100
# 13/13 [==============================] - 3s 228ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 74/100
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 75/100
# 13/13 [==============================] - 2s 185ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 76/100
# 13/13 [==============================] - 2s 163ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 77/100
# 13/13 [==============================] - 2s 164ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 78/100
# 13/13 [==============================] - 2s 168ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 79/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 80/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 81/100
# 13/13 [==============================] - 2s 179ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 82/100
# 13/13 [==============================] - 3s 255ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 83/100
# 13/13 [==============================] - 3s 230ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 84/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 85/100
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 86/100
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 87/100
# 13/13 [==============================] - 3s 222ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 88/100
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 89/100
# 13/13 [==============================] - 2s 175ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 90/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 91/100
# 13/13 [==============================] - 2s 155ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 92/100
# 13/13 [==============================] - 2s 162ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 93/100
# 13/13 [==============================] - 2s 170ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 94/100
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 95/100
# 13/13 [==============================] - 2s 147ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 96/100
# 13/13 [==============================] - 2s 148ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 97/100
# 13/13 [==============================] - 2s 151ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 98/100
# 13/13 [==============================] - 2s 166ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 99/100
# 13/13 [==============================] - 2s 154ms/step - loss: 0.0380 - mae: 0.2130
# Epoch 100/100
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0380 - mae: 0.2130

# %%
pred_list = []
n_future_length = len(train)   # for all the dates 
batch = train[0:n_input].reshape((1, n_input, n_features))

for i in range(n_future_length):   
    pred_list.append(model.predict(batch)[0]) 
    batch = np.append(batch[:,1:,:],[[pred_list[i]]],axis=1)

# %%
series = np.array(df['Sunspots'])
forecast = np.array(pred_list)
time = np.array(df.index)

plt.figure(figsize=(20, 5))
plt.plot(time, series)
plt.plot(time, forecast, color='r')
plt.legend(["Sunspots", "Prediction"], loc='best', fontsize='xx-large')
plt.xticks(fontsize=18)
plt.yticks(fontsize=16)
plt.show()
